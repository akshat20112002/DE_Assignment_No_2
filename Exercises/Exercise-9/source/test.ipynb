# %%
import polars as pl 
from datetime import timedelta

# %%
pl_df = pl.read_csv('../data/202306-divvy-tripdata.csv',schema_overrides={"end_station_id":pl.Utf8})
pl_df.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬─────────┬─────────┬───────────┐
# │ ride_id    ┆ rideable_t ┆ started_at ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat ┆ end_lng ┆ member_ca │
# │ ---        ┆ ype        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---     ┆ ---     ┆ sual      │
# │ str        ┆ ---        ┆ str        ┆ str       ┆   ┆ f64       ┆ f64     ┆ f64     ┆ ---       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆         ┆         ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═════════╪═════════╪═══════════╡
# │ 6F1682AC40 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.69    ┆ 41.91   ┆ -87.7   ┆ member    │
# │ EB6F71     ┆ ike        ┆ 13:34:12   ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 14:31:56  ┆   ┆           ┆         ┆         ┆           │
# │ 622A1686D6 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.65    ┆ 41.94   ┆ -87.65  ┆ member    │
# │ 4948EB     ┆ ike        ┆ 01:30:22   ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 01:33:06  ┆   ┆           ┆         ┆         ┆           │
# │ 3C88859D92 ┆ electric_b ┆ 2023-06-20 ┆ 2023-06-2 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.63  ┆ member    │
# │ 6253B4     ┆ ike        ┆ 18:15:49   ┆ 0         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 18:32:05  ┆   ┆           ┆         ┆         ┆           │
# │ EAD8A5E025 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.65    ┆ 41.98   ┆ -87.66  ┆ member    │
# │ 9DEC88     ┆ ike        ┆ 14:56:00   ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 15:00:35  ┆   ┆           ┆         ┆         ┆           │
# │ 5A36F21930 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.66    ┆ 41.99   ┆ -87.65  ┆ member    │
# │ D6A55C     ┆ ike        ┆ 15:03:34   ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 15:07:16  ┆   ┆           ┆         ┆         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴─────────┴─────────┴───────────┘

# %%
pl_df
# Out:
# shape: (999, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬─────────┬─────────┬───────────┐
# │ ride_id    ┆ rideable_t ┆ started_at ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat ┆ end_lng ┆ member_ca │
# │ ---        ┆ ype        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---     ┆ ---     ┆ sual      │
# │ str        ┆ ---        ┆ str        ┆ str       ┆   ┆ f64       ┆ f64     ┆ f64     ┆ ---       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆         ┆         ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═════════╪═════════╪═══════════╡
# │ 6F1682AC40 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.69    ┆ 41.91   ┆ -87.7   ┆ member    │
# │ EB6F71     ┆ ike        ┆ 13:34:12   ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 14:31:56  ┆   ┆           ┆         ┆         ┆           │
# │ 622A1686D6 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.65    ┆ 41.94   ┆ -87.65  ┆ member    │
# │ 4948EB     ┆ ike        ┆ 01:30:22   ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 01:33:06  ┆   ┆           ┆         ┆         ┆           │
# │ 3C88859D92 ┆ electric_b ┆ 2023-06-20 ┆ 2023-06-2 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.63  ┆ member    │
# │ 6253B4     ┆ ike        ┆ 18:15:49   ┆ 0         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 18:32:05  ┆   ┆           ┆         ┆         ┆           │
# │ EAD8A5E025 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.65    ┆ 41.98   ┆ -87.66  ┆ member    │
# │ 9DEC88     ┆ ike        ┆ 14:56:00   ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 15:00:35  ┆   ┆           ┆         ┆         ┆           │
# │ 5A36F21930 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.66    ┆ 41.99   ┆ -87.65  ┆ member    │
# │ D6A55C     ┆ ike        ┆ 15:03:34   ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 15:07:16  ┆   ┆           ┆         ┆         ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …       ┆ …       ┆ …         │
# │ 3B780A995A ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.72    ┆ 41.97   ┆ -87.73  ┆ member    │
# │ 0219E3     ┆ ike        ┆ 08:32:16   ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 08:39:34  ┆   ┆           ┆         ┆         ┆           │
# │ 73EAB52DC6 ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.67    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ 92D9A1     ┆ ike        ┆ 01:07:38   ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 01:14:07  ┆   ┆           ┆         ┆         ┆           │
# │ EAC18E1F19 ┆ electric_b ┆ 2023-06-17 ┆ 2023-06-1 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ E5A05B     ┆ ike        ┆ 20:24:58   ┆ 7         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 20:25:08  ┆   ┆           ┆         ┆         ┆           │
# │ DB04F0278D ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.69716 ┆ 41.9    ┆ -87.66  ┆ member    │
# │ 4E085B     ┆ ike        ┆ 17:47:30   ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 18:01:14  ┆   ┆           ┆         ┆         ┆           │
# │ E113CD59DB ┆ electric_b ┆ 2023-06-29 ┆ 2023-06-2 ┆ … ┆ -87.66    ┆ 41.95   ┆ -87.66  ┆ member    │
# │ 0D940A     ┆ ike        ┆ 10:24:37   ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │            ┆            ┆            ┆ 10:30:05  ┆   ┆           ┆         ┆         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴─────────┴─────────┴───────────┘

# %%
pl_df = pl_df.with_columns([
    pl.col("started_at").str.strptime(pl.Date, format="%Y-%m-%d %H:%M:%S").alias("started_at"),
    pl.col("ended_at").str.strptime(pl.Date, format="%Y-%m-%d %H:%M:%S").alias("ended_at"),
])

# %%
print(pl_df)
# Out:
# shape: (999, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬─────────┬─────────┬───────────┐
# │ ride_id    ┆ rideable_t ┆ started_at ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat ┆ end_lng ┆ member_ca │
# │ ---        ┆ ype        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---     ┆ ---     ┆ sual      │
# │ str        ┆ ---        ┆ date       ┆ date      ┆   ┆ f64       ┆ f64     ┆ f64     ┆ ---       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆         ┆         ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═════════╪═════════╪═══════════╡
# │ 6F1682AC40 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.69    ┆ 41.91   ┆ -87.7   ┆ member    │
# │ EB6F71     ┆ ike        ┆            ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │ 622A1686D6 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.65    ┆ 41.94   ┆ -87.65  ┆ member    │
# │ 4948EB     ┆ ike        ┆            ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │ 3C88859D92 ┆ electric_b ┆ 2023-06-20 ┆ 2023-06-2 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.63  ┆ member    │
# │ 6253B4     ┆ ike        ┆            ┆ 0         ┆   ┆           ┆         ┆         ┆           │
# │ EAD8A5E025 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.65    ┆ 41.98   ┆ -87.66  ┆ member    │
# │ 9DEC88     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │ 5A36F21930 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.66    ┆ 41.99   ┆ -87.65  ┆ member    │
# │ D6A55C     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …       ┆ …       ┆ …         │
# │ 3B780A995A ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.72    ┆ 41.97   ┆ -87.73  ┆ member    │
# │ 0219E3     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ 73EAB52DC6 ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.67    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ 92D9A1     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ EAC18E1F19 ┆ electric_b ┆ 2023-06-17 ┆ 2023-06-1 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ E5A05B     ┆ ike        ┆            ┆ 7         ┆   ┆           ┆         ┆         ┆           │
# │ DB04F0278D ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.69716 ┆ 41.9    ┆ -87.66  ┆ member    │
# │ 4E085B     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ E113CD59DB ┆ electric_b ┆ 2023-06-29 ┆ 2023-06-2 ┆ … ┆ -87.66    ┆ 41.95   ┆ -87.66  ┆ member    │
# │ 0D940A     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴─────────┴─────────┴───────────┘

# %%
pl_df
# Out:
# shape: (999, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬─────────┬─────────┬───────────┐
# │ ride_id    ┆ rideable_t ┆ started_at ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat ┆ end_lng ┆ member_ca │
# │ ---        ┆ ype        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---     ┆ ---     ┆ sual      │
# │ str        ┆ ---        ┆ date       ┆ date      ┆   ┆ f64       ┆ f64     ┆ f64     ┆ ---       │
# │            ┆ str        ┆            ┆           ┆   ┆           ┆         ┆         ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═════════╪═════════╪═══════════╡
# │ 6F1682AC40 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.69    ┆ 41.91   ┆ -87.7   ┆ member    │
# │ EB6F71     ┆ ike        ┆            ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │ 622A1686D6 ┆ electric_b ┆ 2023-06-05 ┆ 2023-06-0 ┆ … ┆ -87.65    ┆ 41.94   ┆ -87.65  ┆ member    │
# │ 4948EB     ┆ ike        ┆            ┆ 5         ┆   ┆           ┆         ┆         ┆           │
# │ 3C88859D92 ┆ electric_b ┆ 2023-06-20 ┆ 2023-06-2 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.63  ┆ member    │
# │ 6253B4     ┆ ike        ┆            ┆ 0         ┆   ┆           ┆         ┆         ┆           │
# │ EAD8A5E025 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.65    ┆ 41.98   ┆ -87.66  ┆ member    │
# │ 9DEC88     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │ 5A36F21930 ┆ electric_b ┆ 2023-06-19 ┆ 2023-06-1 ┆ … ┆ -87.66    ┆ 41.99   ┆ -87.65  ┆ member    │
# │ D6A55C     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …       ┆ …       ┆ …         │
# │ 3B780A995A ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.72    ┆ 41.97   ┆ -87.73  ┆ member    │
# │ 0219E3     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ 73EAB52DC6 ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.67    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ 92D9A1     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ EAC18E1F19 ┆ electric_b ┆ 2023-06-17 ┆ 2023-06-1 ┆ … ┆ -87.68    ┆ 41.92   ┆ -87.68  ┆ member    │
# │ E5A05B     ┆ ike        ┆            ┆ 7         ┆   ┆           ┆         ┆         ┆           │
# │ DB04F0278D ┆ electric_b ┆ 2023-06-18 ┆ 2023-06-1 ┆ … ┆ -87.69716 ┆ 41.9    ┆ -87.66  ┆ member    │
# │ 4E085B     ┆ ike        ┆            ┆ 8         ┆   ┆           ┆         ┆         ┆           │
# │ E113CD59DB ┆ electric_b ┆ 2023-06-29 ┆ 2023-06-2 ┆ … ┆ -87.66    ┆ 41.95   ┆ -87.66  ┆ member    │
# │ 0D940A     ┆ ike        ┆            ┆ 9         ┆   ┆           ┆         ┆         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────────┴─────────┴─────────┴───────────┘

# %%
pl_df.schema
# Out:
# Schema([('ride_id', String),
#         ('rideable_type', String),
#         ('started_at', Date),
#         ('ended_at', Date),
#         ('start_station_name', String),
#         ('start_station_id', String),
#         ('end_station_name', String),
#         ('end_station_id', String),
#         ('start_lat', Float64),
#         ('start_lng', Float64),
#         ('end_lat', Float64),
#         ('end_lng', Float64),
#         ('member_casual', String)])

# %% [markdown]
# ### 1. Count the number bike rides per day.

# %%
daily_counts = pl_df.with_columns(pl.col("started_at").dt.date().alias("date")).group_by("date").agg(pl.count().alias("ride_count")).sort("date")   
daily_counts
# Out:
# /tmp/ipykernel_63218/607038947.py:1: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   daily_counts = pl_df.with_columns(pl.col("started_at").dt.date().alias("date")).group_by("date").agg(pl.count().alias("ride_count")).sort("date")
# shape: (30, 2)
# ┌────────────┬────────────┐
# │ date       ┆ ride_count │
# │ ---        ┆ ---        │
# │ date       ┆ u32        │
# ╞════════════╪════════════╡
# │ 2023-06-01 ┆ 43         │
# │ 2023-06-02 ┆ 40         │
# │ 2023-06-03 ┆ 33         │
# │ 2023-06-04 ┆ 26         │
# │ 2023-06-05 ┆ 31         │
# │ …          ┆ …          │
# │ 2023-06-26 ┆ 21         │
# │ 2023-06-27 ┆ 20         │
# │ 2023-06-28 ┆ 35         │
# │ 2023-06-29 ┆ 26         │
# │ 2023-06-30 ┆ 51         │
# └────────────┴────────────┘

# %% [markdown]
# ### 2. Calculate the average, max, and minimum number of rides per week of the dataset.

# %%
(pl_df.sort("started_at")
.group_by_dynamic("started_at", every="1w", closed="left")
.agg((pl.len().alias("ride_count")))
.select([pl.col("ride_count").mean().alias("avg_rides_per_week"),
pl.col("ride_count").max().alias("max_rides_per_week"),
pl.col("ride_count").min().alias("min_rides_per_week")]))
# Out:
# shape: (1, 3)
# ┌────────────────────┬────────────────────┬────────────────────┐
# │ avg_rides_per_week ┆ max_rides_per_week ┆ min_rides_per_week │
# │ ---                ┆ ---                ┆ ---                │
# │ f64                ┆ u32                ┆ u32                │
# ╞════════════════════╪════════════════════╪════════════════════╡
# │ 199.8              ┆ 286                ┆ 142                │
# └────────────────────┴────────────────────┴────────────────────┘

# %% [markdown]
# ### 3. For each day, calculate how many rides that day is above or below the same day last week.

# %%
(
    pl_df
    .with_columns(pl.col("started_at").dt.date().alias("date"))
    .group_by("date")
    .agg(pl.count().alias("ride_count")).sort('date')
)
# Out:
# /tmp/ipykernel_63218/2690986700.py:5: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("ride_count")).sort('date')
# shape: (30, 2)
# ┌────────────┬────────────┐
# │ date       ┆ ride_count │
# │ ---        ┆ ---        │
# │ date       ┆ u32        │
# ╞════════════╪════════════╡
# │ 2023-06-01 ┆ 43         │
# │ 2023-06-02 ┆ 40         │
# │ 2023-06-03 ┆ 33         │
# │ 2023-06-04 ┆ 26         │
# │ 2023-06-05 ┆ 31         │
# │ …          ┆ …          │
# │ 2023-06-26 ┆ 21         │
# │ 2023-06-27 ┆ 20         │
# │ 2023-06-28 ┆ 35         │
# │ 2023-06-29 ┆ 26         │
# │ 2023-06-30 ┆ 51         │
# └────────────┴────────────┘

# %%
first_last_ride = daily_counts.with_columns([
    pl.col("ride_count").cast(pl.Int32).alias("ride_count"),
    pl.col("ride_count").cast(pl.Int32).shift(7).alias("last_week_ride_count"),
    (
        (pl.col("ride_count").cast(pl.Int32) - pl.col("ride_count").cast(pl.Int32).shift(7))
        .fill_null(0)
    ).alias("diff_from_last_week")
])
print(first_last_ride)
# Out:
# shape: (30, 4)
# ┌────────────┬────────────┬──────────────────────┬─────────────────────┐
# │ date       ┆ ride_count ┆ last_week_ride_count ┆ diff_from_last_week │
# │ ---        ┆ ---        ┆ ---                  ┆ ---                 │
# │ date       ┆ i32        ┆ i32                  ┆ i32                 │
# ╞════════════╪════════════╪══════════════════════╪═════════════════════╡
# │ 2023-06-01 ┆ 43         ┆ null                 ┆ 0                   │
# │ 2023-06-02 ┆ 40         ┆ null                 ┆ 0                   │
# │ 2023-06-03 ┆ 33         ┆ null                 ┆ 0                   │
# │ 2023-06-04 ┆ 26         ┆ null                 ┆ 0                   │
# │ 2023-06-05 ┆ 31         ┆ null                 ┆ 0                   │
# │ …          ┆ …          ┆ …                    ┆ …                   │
# │ 2023-06-26 ┆ 21         ┆ 58                   ┆ -37                 │
# │ 2023-06-27 ┆ 20         ┆ 28                   ┆ -8                  │
# │ 2023-06-28 ┆ 35         ┆ 29                   ┆ 6                   │
# │ 2023-06-29 ┆ 26         ┆ 53                   ┆ -27                 │
# │ 2023-06-30 ┆ 51         ┆ 45                   ┆ 6                   │
# └────────────┴────────────┴──────────────────────┴─────────────────────┘
